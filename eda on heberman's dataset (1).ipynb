# %% [markdown]
# # PROBLEM DISCRIPTION:
#     #The dataset contains cases from a study that was conducted between 1958 and 1970
#     at the University of Chicago's Billings Hospital on the survival of patients
#     who had undergone surgery for breast cancer.

# %%
#eda on heberman's dataset
#here no of data points are 305
#no of features are 4

# %%
#import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#above are required libraries for data_analysis for this problem
#to read the dataset
heber=pd.read_csv('heberman.csv')
heber.set_axis(['age','year of treatment','nodes detected','servival_status '],axis=1,inplace = 'true')
print(heber)
# Out:
#      age  year of treatment  nodes detected  servival_status
# 0     30                 62               3                 1
# 1     30                 65               0                 1
# 2     31                 59               2                 1
# 3     31                 65               4                 1
# 4     33                 58              10                 1
# 5     33                 60               0                 1
# 6     34                 59               0                 2
# 7     34                 66               9                 2
# 8     34                 58              30                 1
# 9     34                 60               1                 1
# 10    34                 61              10                 1
# 11    34                 67               7                 1
# 12    34                 60               0                 1
# 13    35                 64              13                 1
# ...

# %%
print(heber.shape)     #to get the shape of dataset
# Out:
# (305, 4)

# %%
print(heber.head);
# Out:
# <bound method NDFrame.head of      age  year of treatment  nodes detected  servival_status
# 0     30                 62               3                 1
# 1     30                 65               0                 1
# 2     31                 59               2                 1
# 3     31                 65               4                 1
# 4     33                 58              10                 1
# 5     33                 60               0                 1
# 6     34                 59               0                 2
# 7     34                 66               9                 2
# 8     34                 58              30                 1
# 9     34                 60               1                 1
# 10    34                 61              10                 1
# 11    34                 67               7                 1
# 12    34                 60               0                 1
# 13    35                 64              13                 1
# ...

# %%
print(heber.tail)
# Out:
# <bound method NDFrame.tail of      age  year of treatment  nodes detected  servival_status
# 0     30                 62               3                 1
# 1     30                 65               0                 1
# 2     31                 59               2                 1
# 3     31                 65               4                 1
# 4     33                 58              10                 1
# 5     33                 60               0                 1
# 6     34                 59               0                 2
# 7     34                 66               9                 2
# 8     34                 58              30                 1
# 9     34                 60               1                 1
# 10    34                 61              10                 1
# 11    34                 67               7                 1
# 12    34                 60               0                 1
# 13    35                 64              13                 1
# ...

# %%
#here the data set contains 305 rows or data points and 4 coloums or features

# %%
#describe gives all required analysis of data set like mean,std,25% value etc..

# %%
heber.describe()
# Out:
#               age  year of treatment  nodes detected  servival_status
# count  305.000000         305.000000      305.000000        305.000000
# mean    52.531148          62.849180        4.036066          1.265574
# std     10.744024           3.254078        7.199370          0.442364
# min     30.000000          58.000000        0.000000          1.000000
# 25%     44.000000          60.000000        0.000000          1.000000
# 50%     52.000000          63.000000        1.000000          1.000000
# 75%     61.000000          66.000000        4.000000          2.000000
# max     83.000000          69.000000       52.000000          2.000000

# %%
#2d scatter plot
#bivarient analysis
#i am not doing 3D scatter plot due to visualization problem

# %%
heber.plot(kind='scatter',x='nodes detected',y='age')
plt.show()

# %%
#plotting scatter plot to analyze datapoints of age vs nodes detected

# %%
sns.FacetGrid(heber,size=4).map(plt.scatter,'nodes detected','age').add_legend()
plt.show()

# %%
#plotting total data

# %%
heber.plot()
plt.show()

# %%
heber.hist()
plt.legend
plt.show()                #histograms for all features

# %%
sns.pairplot(heber,size=4)        #to know the best features pair plots are plotted 4c2 combinations are possible
plt.show()

# %% [markdown]
# # univarient analysis

# %%
sns.FacetGrid(heber,size=5).map(sns.distplot, "nodes detected").add_legend();
plt.show();
plt.legend;

# %%
#in the above graph most of the points lies in between 0 to 5 in x-axis and 0.2 in y-axis as show in pdf

# %%
sns.FacetGrid(heber, size=5).map(sns.distplot, "age")
plt.show();
plt.legend;

# %%
#in the above plot the age group of people in between 30 to 60

# %%
sns.FacetGrid(heber, size=5).map(sns.distplot, "year of treatment")
plt.show();
plt.legend;

# %%
sns.FacetGrid(heber,size=5).map(sns.distplot,"nodes detected")
plt.show();
plt.legend;

# %% [markdown]
# # box plots and violin plots

# %%
sns.boxplot(x='nodes detected',y='age', data=heber)
plt.show()

# %%
sns.boxplot(x='nodes detected',y='year of treatment', data=heber)
plt.show()

# %%
sns.violinplot(x='year of treatment', y='nodes detected', data=heber, size=6)
plt.show()

# %%
sns.violinplot(x="nodes detected", y="year of treatment", data=heber, size=2)
plt.show()

# %% [markdown]
# # conclution

# %%
1:  the servival_status tells that 1 represents patient survived after the treatment about 5 years or longer
    and 2 represents patient died within 5 years of treatment

# %%
2:  most number of nodes detected at the year 64 and less number of nodes detected at the year 60

# %%
3:  when the age increases the number of deteceted nodes increases
